# %%
import os
import itertools
import glob
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.ticker
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager, FontProperties

path = "/Users/gov/Library/Fonts/cmunss.ttf"
fontManager.addfont(path)

sns.set(font_scale=0.9, style='whitegrid', font='CMU Sans Serif')
pal = sns.color_palette(['#4477AA', '#EE6677', '#228833', '#CCBB44', '#66CCEE', '#AA3377', '#BBBBBB'])
sns.set_palette(pal)

mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['figure.figsize'] = (4.5,2)
mpl.rcParams['figure.dpi'] = 100

# %%
infile = "perfChanges.pkl"
df_results = pd.read_pickle(infile)
df_accuracy = pd.read_pickle("accuracy.pkl")

# %%
platformText="aws"
color1 = "blue"
color2 = "gray"
color3= "black"
alpha = 0.8
msize=70
x_min=-1
x_max=3
plt.hlines(0,xmin=x_min, xmax=x_max, color="red")

plt.ylim(-4,10)
plt.xlim(x_min,x_max)
plt.xlabel("Approach")
plt.ylabel("Detected Change in %")

subset = df_results.loc[(df_results["regression"] == 0)
                             & (df_results["platform"] == "aws")
                             & (df_results["resultCount"] == 1500)
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "traditional")
]

sns.scatterplot(data=subset, x="method", y="change", c=color1, marker="D", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="min", c=color1, marker="^", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="max", c=color1, marker="v", alpha=alpha, s=msize)

subset = df_results.loc[(df_results["regression"] == 0)
                             & (df_results["platform"] == "aws")
                             & (df_results["resultCount"] == 1500)
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "faasterBench")
]
 
sns.scatterplot(data=subset, x="method", y="change", c=color2, marker="D", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="min", c=color2, marker="^", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="max", c=color2, marker="v", alpha=alpha, s=msize)


subset = df_results.loc[(df_results["regression"] == 0)
                             & (df_results["platform"] == "aws")
                             & (df_results["resultCount"] == 1500)
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "DuetFaaS")
]
sns.scatterplot(data=subset, x="method", y="change", c=color3, marker="D", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="min", c=color3, marker="^", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="max", c=color3, marker="v", alpha=alpha, s=msize)
plt.savefig("ci_cpu_0.pdf",bbox_inches='tight')
plt.show()
# Out:
# webf NOT subset; don't know how to subset; dropped

# %%
platformText="aws"
color1 = "blue"
color2 = "gray"
color3= "black"
alpha = 0.8
msize=70

plt.hlines(5,xmin=x_min, xmax=x_max, color="red")

plt.ylim(-4,10)
plt.xlim(x_min, x_max)
plt.xlabel("Approach")
plt.ylabel("Detected Change in %")

subset = df_results.loc[(df_results["regression"] == 5)
                             & (df_results["platform"] == "aws") 
                             & (df_results["resultCount"] == 1500)                      
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "traditional")
]

sns.scatterplot(data=subset, x="method", y="change", c=color1, marker="D", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="min", c=color1, marker="^", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="max", c=color1, marker="v", alpha=alpha, s=msize)

subset = df_results.loc[(df_results["regression"] == 5)
                             & (df_results["platform"] == "aws")
                             & (df_results["resultCount"] == 1500)
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "faasterBench")
]

sns.scatterplot(data=subset, x="method", y="change", c=color2, marker="D", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="min", c=color2, marker="^", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="max", c=color2, marker="v", alpha=alpha, s=msize)


subset = df_results.loc[(df_results["regression"] == 5)
                             & (df_results["platform"] == "aws")
                             & (df_results["resultCount"] == 1500)
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "DuetFaaS")
]
print(subset)
sns.scatterplot(data=subset, x="method", y="change", c=color3, marker="D", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="min", c=color3, marker="^", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="max", c=color3, marker="v", alpha=alpha, s=msize)
plt.savefig("ci_cpu_5.pdf",bbox_inches='tight')
plt.show()
# Out:
# webf NOT subset; don't know how to subset; dropped
#      platform functionType  regression    method    change       min  \
# 3489      aws          cpu           5  DuetFaaS  5.263158  5.263158
#
#            max  resultCount
# 3489  5.263158         1500

# %%
platformText="aws"
color1 = "blue"
color2 = "gray"
color3= "black"
alpha = 0.8
msize=70

plt.hlines(0,xmin=x_min, xmax=x_max, color="red")

plt.ylim(-4,10)
plt.xlim(x_min,x_max)
plt.xlabel("Approach")
plt.ylabel("Detected Change in %")

subset = df_results.loc[(df_results["regression"] == 0)
                             & (df_results["platform"] == "aws")
                             & (df_results["resultCount"] == 1500)
                             & (df_results["functionType"] == "mem")
                             & (df_results["method"] == "traditional")
]

sns.scatterplot(data=subset, x="method", y="change", c=color1, marker="D", alpha=alpha, s=msize, )
sns.scatterplot(data=subset, x="method", y="min", c=color1, marker="^", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="max", c=color1, marker="v", alpha=alpha, s=msize)

subset = df_results.loc[(df_results["regression"] == 0)
                             & (df_results["platform"] == "aws")
                             & (df_results["resultCount"] == 1500)
                             & (df_results["functionType"] == "mem")
                             & (df_results["method"] == "faasterBench")
]
sns.scatterplot(data=subset, x="method", y="change", c=color2, marker="D", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="min", c=color2, marker="^", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="max", c=color2, marker="v", alpha=alpha, s=msize)


subset = df_results.loc[(df_results["regression"] == 0)
                             & (df_results["platform"] == "aws")
                             & (df_results["resultCount"] == 1500)
                             & (df_results["functionType"] == "mem")
                             & (df_results["method"] == "DuetFaaS")
]
sns.scatterplot(data=subset, x="method", y="change", c=color3, marker="D", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="min", c=color3, marker="^", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="max", c=color3, marker="v", alpha=alpha, s=msize)
plt.savefig("ci_mem_0.pdf",bbox_inches='tight')
plt.show()
# Out:
# webf NOT subset; don't know how to subset; dropped

# %%
platformText="aws"
color1 = "blue"
color2 = "gray"
color3= "black"
alpha = 0.8
msize=70

plt.hlines(5,xmin=x_min, xmax=x_max,color="red")

plt.ylim(-4,10)
plt.xlim(x_min,x_max)
plt.xlabel("Approach")
plt.ylabel("Detected Change in %")
subset = df_results.loc[(df_results["regression"] == 5)
                             & (df_results["platform"] == "aws")
                             & (df_results["resultCount"] == 1500)
                             & (df_results["functionType"] == "mem")
                             & (df_results["method"] == "traditional")
]

sns.scatterplot(data=subset, x="method", y="change", c=color1, marker="D", alpha=alpha, s=msize, )
sns.scatterplot(data=subset, x="method", y="min", c=color1, marker="^", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="max", c=color1, marker="v", alpha=alpha, s=msize)

subset = df_results.loc[(df_results["regression"] == 5)
                             & (df_results["platform"] == "aws")
                             & (df_results["resultCount"] == 1500)
                             & (df_results["functionType"] == "mem")
                             & (df_results["method"] == "faasterBench")
]

sns.scatterplot(data=subset, x="method", y="change", c=color2, marker="D", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="min", c=color2, marker="^", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="max", c=color2, marker="v", alpha=alpha, s=msize)


subset = df_results.loc[(df_results["regression"] == 5)
                             & (df_results["platform"] == "aws")
                             & (df_results["resultCount"] == 1500)
                             & (df_results["functionType"] == "mem")
                             & (df_results["method"] == "DuetFaaS")
]

sns.scatterplot(data=subset, x="method", y="change", c=color3, marker="D", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="min", c=color3, marker="^", alpha=alpha, s=msize)
sns.scatterplot(data=subset, x="method", y="max", c=color3, marker="v", alpha=alpha, s=msize)
plt.savefig("ci_mem_5.pdf",bbox_inches='tight')
plt.show()
# Out:
# webf NOT subset; don't know how to subset; dropped

# %%
fig, axs = plt.subplots(1, , sharex=True, sharey=True,)
platformText="aws"
color1 = "blue"
color2 = "gray"
color3= "black"
alpha = 0.8
msize=70

axs[0].set_ylim(-4,10)
axs[0].xlim(-1,6)
df_results["regression"]
dx, dy = 0.15, 0.
offset = transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)
subset = df_results.loc[(df_results["regression"] == 0)
                             & (df_results["platform"] == "aws")
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "traditional")
]

shiftLeft =axs[0].transData - offset
axs[0].scatter(subset["regression"],subset["change"], c=color1, marker="D", alpha=alpha, s=msize, transform=shiftLeft)
axs[0].scatter(subset["regression"],subset["min"], c=color1, marker="^", alpha=alpha, s=msize, transform=shiftLeft)
axs[0].scatter(subset["regression"],subset["max"], c=color1, marker="v", alpha=alpha, s=msize, transform=shiftLeft)

subset = df_results.loc[(df_results["regression"] == 0)
                             & (df_results["platform"] == "aws")
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "faasterBench")
]

shiftMid =axs[0].transData 
axs[0].scatter(subset["regression"],subset["change"], c=color2, marker="D", alpha=alpha, s=msize)
axs[0].scatter(subset["regression"],subset["min"], c=color2, marker="^", alpha=alpha, s=msize)
axs[0].scatter(subset["regression"],subset["max"], c=color2, marker="v", alpha=alpha, s=msize)


subset = df_results.loc[(df_results["regression"] == 0)
                             & (df_results["platform"] == "aws")
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "DuetFaaS")
]
shiftRightTwice =axs[0].transData + offset
axs[0].scatter(subset["regression"],subset["change"], c=color3, marker="D", alpha=alpha, s=msizeTwice)
axs[0].scatter(subset["regression"],subset["min"], c=color3, marker="^", alpha=alpha, s=msizeTwice)
axs[0].scatter(subset["regression"],subset["max"], c=color3, marker="v", alpha=alpha, s=msizeTwice)
axs[0].title('0% regression', fontdict={'size' : 18 })


#5 regression
subset = df_results.loc[(df_results["regression"] == 5)
                             & (df_results["platform"] == "aws")
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "traditional")
]

shiftLeft =axs[0].transData - offset
axs[0].scatter(subset["regression"],subset["change"], c=color1, marker="D", alpha=alpha, s=msize)
axs[0].scatter(subset["regression"],subset["min"], c=color1, marker="^", alpha=alpha, s=msize)
axs[0].scatter(subset["regression"],subset["max"], c=color1, marker="v", alpha=alpha, s=msize)

subset = df_results.loc[(df_results["regression"] == 5)
                             & (df_results["platform"] == "aws")
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "faasterBench")
]

shiftLeft =axs[0].transData
axs[0].scatter(subset["regression"],subset["change"], c=color2, marker="D", alpha=alpha, s=msize, transform=shiftLeft)
axs[0].scatter(subset["regression"],subset["min"], c=color2, marker="^", alpha=alpha, s=msize, transform=shiftLeft)
axs[0].scatter(subset["regression"],subset["max"], c=color2, marker="v", alpha=alpha, s=msize, transform=shiftLeft)



subset = df_results.loc[(df_results["regression"] == 5)
                             & (df_results["platform"] == "aws")
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "DuetFaaS")
]
print(subset)
shiftRightTwice =axs[0].transData + offset
axs[0].scatter(subset["regression"],subset["change"], c=color3, marker="D", alpha=alpha, s=msizeTwice)
axs[0].scatter(subset["regression"],subset["min"], c=color3, marker="^", alpha=alpha, s=msizeTwice)
axs[0].scatter(subset["regression"],subset["max"], c=color3, marker="v", alpha=alpha, s=msizeTwice)
axs[0].title("CPU", fontdict={'size' : 18 })

axs[1].set_ylim(-4,10)
axs[1].xlim(-1,6)
df_results["regression"]
dx, dy = 0.15, 0.
offset = transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)
subset = df_results.loc[(df_results["regression"] == 0)
                             & (df_results["platform"] == "aws")
                             & (df_results["functionType"] == "mem")
                             & (df_results["method"] == "traditional")
]

shiftLeft =axs[1].transData - offset
axs[1].scatter(subset["regression"],subset["change"], c=color1, marker="D", alpha=alpha, s=msize, transform=shiftLeft)
axs[1].scatter(subset["regression"],subset["min"], c=color1, marker="^", alpha=alpha, s=msize, transform=shiftLeft)
axs[1].scatter(subset["regression"],subset["max"], c=color1, marker="v", alpha=alpha, s=msize, transform=shiftLeft)

subset = df_results.loc[(df_results["regression"] == 0)
                             & (df_results["platform"] == "aws")
                             & (df_results["functionType"] == "mem")
                             & (df_results["method"] == "faasterBench")
]

shiftMid =axs[1].transData 
axs[1].scatter(subset["regression"],subset["change"], c=color2, marker="D", alpha=alpha, s=msize)
axs[1].scatter(subset["regression"],subset["min"], c=color2, marker="^", alpha=alpha, s=msize)
axs[1].scatter(subset["regression"],subset["max"], c=color2, marker="v", alpha=alpha, s=msize)


subset = df_results.loc[(df_results["regression"] == 0)
                             & (df_results["platform"] == "aws")
                             & (df_results["functionType"] == "mem")
                             & (df_results["method"] == "DuetFaaS")
]
shiftRightTwice =axs[1].transData + offset
axs[1].scatter(subset["regression"],subset["change"], c=color3, marker="D", alpha=alpha, s=msizeTwice)
axs[1].scatter(subset["regression"],subset["min"], c=color3, marker="^", alpha=alpha, s=msizeTwice)
axs[1].scatter(subset["regression"],subset["max"], c=color3, marker="v", alpha=alpha, s=msizeTwice)
axs[1].title('0% regression', fontdict={'size' : 18 })


#5 regression
subset = df_results.loc[(df_results["regression"] == 5)
                             & (df_results["platform"] == "aws")
                             & (df_results["functionType"] == "mem")
                             & (df_results["method"] == "traditional")
]

shiftLeft =axs[1].transData - offset
axs[1].scatter(subset["regression"],subset["change"], c=color1, marker="D", alpha=alpha, s=msize, transform=shiftLeft)
axs[1].scatter(subset["regression"],subset["min"], c=color1, marker="^", alpha=alpha, s=msize, transform=shiftLeft)
axs[1].scatter(subset["regression"],subset["max"], c=color1, marker="v", alpha=alpha, s=msize, transform=shiftLeft)

subset = df_results.loc[(df_results["regression"] == 5)
                             & (df_results["platform"] == "aws")
                             & (df_results["functionType"] == "mem")
                             & (df_results["method"] == "faasterBench")
]

shiftLeft =axs[1].transData
axs[1].scatter(subset["regression"],subset["change"], c=color2, marker="D", alpha=alpha, s=msize, transform=shiftLeft)
axs[1].scatter(subset["regression"],subset["min"], c=color2, marker="^", alpha=alpha, s=msize, transform=shiftLeft)
axs[1].scatter(subset["regression"],subset["max"], c=color2, marker="v", alpha=alpha, s=msize, transform=shiftLeft)



subset = df_results.loc[(df_results["regression"] == 5)
                             & (df_results["platform"] == "aws")
                             & (df_results["functionType"] == "mem")
                             & (df_results["method"] == "DuetFaaS")
]
print(subset)
shiftRightTwice =axs[1].transData + offset
axs[1].scatter(subset["regression"],subset["change"], c=color3, marker="D", alpha=alpha, s=msizeTwice)
axs[1].scatter(subset["regression"],subset["min"], c=color3, marker="^", alpha=alpha, s=msizeTwice)
axs[1].scatter(subset["regression"],subset["max"], c=color3, marker="v", alpha=alpha, s=msizeTwice)
axs[1].title("Mem", fontdict={'size' : 18 })

first = True
for ax in axs.flat:
    ax.set_xlabel('Regression', fontdict={'size': 14 })
    ax.set_ylabel('Detected Change (%)', fontdict={'size': 14 })
    ax.tick_params(labelsize=14)
    ax.label_outer()

fig.legend(['Trad. Median', 'Trad. Min', 'Trad. Max', 'RMIT Median', 'RMIT Min','RMIT Max','Duet Median', 'Duet Min','Duet Max'],
           ncol=3, loc="lower center", bbox_to_anchor=(0.5, -0.1), fontsize=12)

plt.savefig("cpu_results.pdf",bbox_inches='tight')
# Out:
#   Cell In[8], line 1
#     fig, axs = plt.subplots(1, , sharex=True, sharey=True,)
#                                ^
# SyntaxError: invalid syntax

# %%
fig, axs = plt.subplots(1, 2, sharex=True, sharey=True,)
platformText="aws"
color1 = "blue"
color2 = "gray"
alpha = 0.8
msize=70

axs[0].set_ylim(-4,15)
axs[0].xlim(-0.5,2.5)

dx, dy = 0.15, 0.
offset = transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# subset = df_results.loc[(df_results["platform"] == platformText)
#                              & (df_results["regression"] == 0)                             
#                              & (df_results["method"] == "faasterBench")
# ]

# shiftRight =axs[0,0].transData + offset
# axs[0, 0].scatter(subset["callsPerFunction"], subset["change"], c=color1, marker="D", alpha=alpha, s=msize)
# axs[0, 0].scatter(subset["callsPerFunction"], subset["min"], c=color1, marker="^", alpha=alpha, s=msize)
# axs[0, 0].scatter(subset["callsPerFunction"], subset["max"], c=color1, marker="v", alpha=alpha, s=msize)

# subset = df_results.loc[(df_results["platform"] == platformText)
#                              & (df_results["regression"] == 0)
#                              & (df_results["method"] == "traditional")
# ]     

# shiftLeft = axs[0,0].transData - offset
# axs[0, 0].scatter(subset["callsPerFunction"], subset["change"], c=color2, marker="D", alpha=alpha, s=msize, transform=shiftLeft)
# axs[0, 0].scatter(subset["callsPerFunction"], subset["min"], c=color2, marker="^", alpha=alpha, s=msize, transform=shiftLeft)
# axs[0, 0].scatter(subset["callsPerFunction"], subset["max"], c=color2, marker="v", alpha=alpha, s=msize, transform=shiftLeft)

# axs[0, 0].title('0% regression, 5 wrappers', fontdict={'size' : 18 })


# subset = df_results.loc[(df_results["platform"] == platformText)
#                              & (df_results["regression"] == 0)
#                              & (df_results["method"] == "faasterBench")
# ]

# shiftRight =axs[0].transData + offset
# axs[0].scatter(subset["callsPerFunction"], subset["change"], c=color1, marker="D", alpha=alpha, s=msize)
# axs[0].scatter(subset["callsPerFunction"], subset["min"], c=color1, marker="^", alpha=alpha, s=msize)
# axs[0].scatter(subset["callsPerFunction"], subset["max"], c=color1, marker="v", alpha=alpha, s=msize)

# subset = df_results.loc[(df_results["platform"] == platformText)
#                              & (df_results["regression"] == 0)
#                              & (df_results["method"] == "traditional")
# ]
# shiftLeft = axs[0].transData - offset
# axs[0].scatter(subset["callsPerFunction"], subset["change"], c=color2, marker="D", alpha=alpha, s=msize, transform=shiftLeft)
# axs[0].scatter(subset["callsPerFunction"], subset["min"], c=color2, marker="^", alpha=alpha, s=msize, transform=shiftLeft)
# axs[0].scatter(subset["callsPerFunction"], subset["max"], c=color2, marker="v", alpha=alpha, s=msize, transform=shiftLeft)

# axs[0].title('5% regression, 5 wrappers', fontdict={'size' : 18 })


# subset = df_results.loc[(df_results["platform"] == platformText)
#                              & (df_results["regression"] == 0)
#                              & (df_results["method"] == "faasterBench")
# ]

# shiftRight =axs[0,0].transData + offset
# axs[0, 0].scatter(subset["callsPerFunction"], subset["change"], c=color1, marker="D", alpha=alpha, s=msize)
# axs[0, 0].scatter(subset["callsPerFunction"], subset["min"], c=color1, marker="^", alpha=alpha, s=msize)
# axs[0, 0].scatter(subset["callsPerFunction"], subset["max"], c=color1, marker="v", alpha=alpha, s=msize)

# subset = df_results.loc[(df_results["platform"] == platformText)
#                              & (df_results["regression"] == 0)
#                              & (df_results["method"] == "traditional")
# ]
# shiftLeft = axs[0,0].transData - offset
# axs[0, 0].scatter(subset["callsPerFunction"], subset["change"], c=color2, marker="D", alpha=alpha, s=msize, transform=shiftLeft)
# axs[0, 0].scatter(subset["callsPerFunction"], subset["min"], c=color2, marker="^", alpha=alpha, s=msize, transform=shiftLeft)
# axs[0, 0].scatter(subset["callsPerFunction"], subset["max"], c=color2, marker="v", alpha=alpha, s=msize, transform=shiftLeft)

# axs[0, 0].title('0% regression, 10 wrappers', fontdict={'size' : 18 })
#0 regression
subset = df_results.loc[(df_results["regression"] == 0)
                             & (df_results["platform"] == "aws")
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "traditional")
]

shiftLeft =axs[0].transData - offset
axs[0].scatter(subset["regression"],subset["change"], c=color1, marker="D", alpha=alpha, s=msize, transform=shiftLeft)
axs[0].scatter(subset["regression"],subset["min"], c=color1, marker="^", alpha=alpha, s=msize, transform=shiftLeft)
axs[0].scatter(subset["regression"],subset["max"], c=color1, marker="v", alpha=alpha, s=msize, transform=shiftLeft)

subset = df_results.loc[(df_results["regression"] == 0)
                             & (df_results["platform"] == "google")
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "traditional")
]

shiftRight =axs[0].transData + offset
axs[0].scatter(subset["regression"],subset["change"], c=color2, marker="D", alpha=alpha, s=msize)
axs[0].scatter(subset["regression"],subset["min"], c=color2, marker="^", alpha=alpha, s=msize)
axs[0].scatter(subset["regression"],subset["max"], c=color2, marker="v", alpha=alpha, s=msize)


subset = df_results.loc[(df_results["regression"] == 0)
                             & (df_results["platform"] == "aws")
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "faasterBench")
]

shiftLeft =axs[0].transData - offset
axs[0].scatter(subset["regression"],subset["change"], c=color1, marker="D", alpha=alpha, s=msize, transform=shiftLeft)
axs[0].scatter(subset["regression"],subset["min"], c=color1, marker="^", alpha=alpha, s=msize, transform=shiftLeft)
axs[0].scatter(subset["regression"],subset["max"], c=color1, marker="v", alpha=alpha, s=msize, transform=shiftLeft)


subset = df_results.loc[(df_results["regression"] == 0)
                             & (df_results["platform"] == "google")
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "faasterBench")
]
shiftRight =axs[0].transData + offset
axs[0].scatter(subset["regression"],subset["change"], c=color2, marker="D", alpha=alpha, s=msize)
axs[0].scatter(subset["regression"],subset["min"], c=color2, marker="^", alpha=alpha, s=msize)
axs[0].scatter(subset["regression"],subset["max"], c=color2, marker="v", alpha=alpha, s=msize)




subset = df_results.loc[(df_results["regression"] == 0)
                             & (df_results["platform"] == "aws")
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "DuetFaaS")
]
shiftRightTwice =axs[0].transData
axs[0].scatter(subset["regression"],subset["change"], c=color1, marker="D", alpha=alpha, s=msizeTwice)
axs[0].scatter(subset["regression"],subset["min"], c=color1, marker="^", alpha=alpha, s=msizeTwice)
axs[0].scatter(subset["regression"],subset["max"], c=color1, marker="v", alpha=alpha, s=msizeTwice)
axs[0].title('0% regression', fontdict={'size' : 18 })


#5 regression
subset = df_results.loc[(df_results["regression"] == 5)
                             & (df_results["platform"] == "aws")
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "traditional")
]

shiftLeft =axs[0].transData - offset
axs[0].scatter(subset["regression"],subset["change"], c=color1, marker="D", alpha=alpha, s=msize, transform=shiftLeft)
axs[0].scatter(subset["regression"],subset["min"], c=color1, marker="^", alpha=alpha, s=msize, transform=shiftLeft)
axs[0].scatter(subset["regression"],subset["max"], c=color1, marker="v", alpha=alpha, s=msize, transform=shiftLeft)

subset = df_results.loc[(df_results["regression"] == 5)
                             & (df_results["platform"] == "google")
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "traditional")
]

shiftRight =axs[0].transData + offset
axs[0].scatter(subset["regression"],subset["change"], c=color2, marker="D", alpha=alpha, s=msize)
axs[0].scatter(subset["regression"],subset["min"], c=color2, marker="^", alpha=alpha, s=msize)
axs[0].scatter(subset["regression"],subset["max"], c=color2, marker="v", alpha=alpha, s=msize)


subset = df_results.loc[(df_results["regression"] == 5)
                             & (df_results["platform"] == "aws")
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "faasterBench")
]

shiftLeft =axs[0].transData - offset
axs[0].scatter(subset["regression"],subset["change"], c=color1, marker="D", alpha=alpha, s=msize, transform=shiftLeft)
axs[0].scatter(subset["regression"],subset["min"], c=color1, marker="^", alpha=alpha, s=msize, transform=shiftLeft)
axs[0].scatter(subset["regression"],subset["max"], c=color1, marker="v", alpha=alpha, s=msize, transform=shiftLeft)


subset = df_results.loc[(df_results["regression"] == 5)
                             & (df_results["platform"] == "google")
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "faasterBench")
]
shiftRight =axs[0].transData + offset
axs[0].scatter(subset["regression"],subset["change"], c=color2, marker="D", alpha=alpha, s=msize)
axs[0].scatter(subset["regression"],subset["min"], c=color2, marker="^", alpha=alpha, s=msize)
axs[0].scatter(subset["regression"],subset["max"], c=color2, marker="v", alpha=alpha, s=msize)




subset = df_results.loc[(df_results["regression"] == 5)
                             & (df_results["platform"] == "aws")
                             & (df_results["functionType"] == "cpu")
                             & (df_results["method"] == "DuetFaaS")
]
print(subset)
shiftRightTwice =axs[0].transData
axs[0].scatter(subset["regression"],subset["change"], c=color1, marker="D", alpha=alpha, s=msizeTwice)
axs[0].scatter(subset["regression"],subset["min"], c=color1, marker="^", alpha=alpha, s=msizeTwice)
axs[0].scatter(subset["regression"],subset["max"], c=color1, marker="v", alpha=alpha, s=msizeTwice)
axs[0].title('5% regression', fontdict={'size' : 18 })

first = True
for ax in axs.flat:
    ax.set_xlabel('Approach', fontdict={'size': 14 })
    ax.set_ylabel('Detected Change (%)', fontdict={'size': 14 })
    ax.tick_params(labelsize=14)
    ax.label_outer()

fig.legend(['AWS Median', 'AWS Min', 'AWS Max', 'GCP Median', 'GCP Min','GCP Max'],
           ncol=2, loc="lower center", bbox_to_anchor=(0.5, -0.1), fontsize=12)

plt.savefig("mem_results.pdf",bbox_inches='tight')
# Out:
#    platform functionType  regression    method    change       min       max
# 0       aws          mem           5  DuetFaaS -4.109589 -4.411765 -2.941176
# 20      aws          mem           5  DuetFaaS -4.109589 -4.444688 -2.941176

# %%
sns.scatterplot(data=df_accuracy, x="measurements", y="deviation", hue="method", style="regression")
# Out:
# <AxesSubplot:xlabel='measurements', ylabel='deviation'>

# %%
sns.scatterplot(data=df_accuracy, x="measurements", y="CIWidth", hue="method", style="regression")
# Out:
# <AxesSubplot:xlabel='measurements', ylabel='CIWidth'>

# %%
subsetfaaster = df_results.loc[(df_results["platform"] == platformText)
                             & (df_results["regression"] == 5)
                             & (df_results["method"] == "faasterBench")
                             
print(subsetfaaster)
subsettraditional = df_results.loc[(df_results["platform"] == platformText)
                             & (df_results["method"] == "faasterBench")
                             
plt.hist([subsetfaaster, subsettraditional], color=['r','b'], alpha=0.5)
# Out:
#    platform  regression  wrapperCount callsPerFunction  callsPerFunctionInt  \
# 8       aws           5             5                5                    5
# 2       aws           5            10                5                    5
# 0       aws           5            10               10                   10
# 6       aws           5             5               10                   10
# 10      aws           5             5               25                   25
# 4       aws           5            10               25                   25
#
#     iterations        method    change       min       max
# 8            3  faasterBench  5.191257  4.408818  5.547945
# 2            3  faasterBench  5.441389  5.097528  5.786507
# 0            3  faasterBench  5.446575  5.266758  5.614973
# 6            3  faasterBench  5.184634  4.787234  5.379845
# 10           3  faasterBench  5.400130  5.270363  5.544287
# 4            3  faasterBench  5.338323  5.195682  5.407210
# ...
